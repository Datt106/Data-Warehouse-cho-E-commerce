# %% [markdown]
# # 1. Tạo catalog

# %%
# %sql
create catalog if not exists brazilian_ecommerce;

# %% [markdown]
# # 2. Tạo Schema

# %%
# %sql
use catalog brazilian_ecommerce;
create schema if not exists bronze;
create schema if not exists silver;
create schema if not exists gold;
create schema if not exists business;

# %% [markdown]
# # 3. Set đường dẫn

# %%
from pyspark.sql.functions import current_timestamp, input_file_name, col

# --- CẤU HÌNH ĐƯỜNG DẪN ---
# Thay đổi đường dẫn này tới nơi bạn chứa file CSV raw
raw_data_path = "/Volumes/brazilian_ecommerce/bronze/raw_data/archive/" 

# Đường dẫn lưu trữ Checkpoint cho Auto Loader (Bắt buộc để streaming hoạt động)
checkpoint_base_path = "/Volumes/brazilian_ecommerce/bronze/check_points"

# Tên Catalog và Schema (Database)
catalog_name = "brazilian_ecommerce" # Nếu chưa có Unity Catalog thì bỏ dòng này
schema_name = "bronze"

print(f"Source Path: {raw_data_path}")
print(f"Target Schema: {schema_name}")
